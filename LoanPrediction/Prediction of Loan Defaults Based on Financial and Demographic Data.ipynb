# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('bank.csv')

# %% [markdown]
# ### Basic EDA

# %%
df.head()
# Out:
#    age  job  marital  education  default  balance  housing  loan  contact  \
# 0   59    0        1          1        0     2343        1     0        2
# 1   56    0        1          1        0       45        0     0        2
# 2   41    9        1          1        0     1270        1     0        2
# 3   55    7        1          1        0     2476        1     0        2
# 4   54    0        1          2        0      184        0     0        2
#
#    day  month  duration  campaign  pdays  previous  poutcome  deposit
# 0    5      8      1042         1     -1         0         3        1
# 1    5      8      1467         1     -1         0         3        1
# 2    5      8      1389         1     -1         0         3        1
# 3    5      8       579         1     -1         0         3        1
# 4    5      8       673         2     -1         0         3        1

# %%
df.tail()
# Out:
#        age  job  marital  education  default  balance  housing  loan  contact  \
# 11157   33    1        2          0        0        1        1     0        0
# 11158   39    7        1          1        0      733        0     0        2
# 11159   32    9        2          1        0       29        0     0        0
# 11160   43    9        1          1        0        0        0     1        0
# 11161   34    9        1          1        0        0        0     0        0
#
#        day  month  duration  campaign  pdays  previous  poutcome  deposit
# 11157   20      0       257         1     -1         0         3        0
# 11158   16      6        83         4     -1         0         3        0
# 11159   19      1       156         2     -1         0         3        0
# 11160    8      8         9         2    172         5         0        0
# 11161    9      5       628         1     -1         0         3        0

# %%
df.shape
# Out:
# (11162, 17)

# %%
df.describe()
# Out:
#                 age           job       marital     education       default  \
# count  11162.000000  11162.000000  11162.000000  11162.000000  11162.000000
# mean      41.231948      4.487905      1.199337      1.285164      0.015051
# std       11.913369      3.225132      0.625552      0.749478      0.121761
# min       18.000000      0.000000      0.000000      0.000000      0.000000
# 25%       32.000000      1.000000      1.000000      1.000000      0.000000
# 50%       39.000000      4.000000      1.000000      1.000000      0.000000
# 75%       49.000000      7.000000      2.000000      2.000000      0.000000
# max       95.000000     11.000000      2.000000      3.000000      1.000000
#
#             balance       housing          loan       contact           day  \
# count  11162.000000  11162.000000  11162.000000  11162.000000  11162.000000
# mean    1528.538524      0.473123      0.130801      0.489697     15.658036
# ...

# %%
df.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# deposit      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Advance EDA

# %%
sns.boxplot( x='age', data=df)
plt.figtext(0.5, -0.1, 'From this, we can see that Age has outliers', ha='center', color='green')
# Out:
# Text(0.5, -0.1, 'From this, we can see that Age has outliers')

# %%
sns.scatterplot( x='balance', y = 'duration' ,data=df)
plt.figtext(0.5, -0.05, 'Through this data, we can see that most people hold balance upto 40k until 2700', ha='center', fontsize=10, color='green')
# Out:
# Text(0.5, -0.05, 'Through this data, we can see that most people hold balance upto 40k until 2700')

# %%
sns.countplot(x = 'job', data = df)
plt.figtext(0.5, -0.05, 'Through this data, we can see that most people hold jobs 4 then 9 then 1', ha='center',fontsize=10, color='green')
# Out:
# Text(0.5, -0.05, 'Through this data, we can see that most people hold jobs 4 then 9 then 1')

# %%
sns.countplot(x = 'deposit', data = df)
plt.figtext(0.5, -0.05, 'Through this data, we can see that more people hold deposits', ha='center',fontsize=10, color='green')
# Out:
# Text(0.5, -0.05, 'Through this data, we can see that more people hold deposits')

# %%
sns.heatmap(pd.crosstab(df['deposit'],df['default']))
plt.figtext(0.5, -0.05, 'Through this data, we can see that people with no deposit have higher chance of default', ha='center',fontsize=10, color='green')
# Out:
# Text(0.5, -0.05, 'Through this data, we can see that people with no deposit have higher chance of default')

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(), cmap = 'coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# ### Handling Outlier

# %%
percentile25 = df['age'].quantile(0.25)
percentile75 = df['age'].quantile(0.75)

iqr = percentile75 - percentile25
upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr

print("Upper limit",upper_limit)
print("Lower limit",lower_limit)
# Out:
# Upper limit 74.5
# Lower limit 6.5

# %%
df = df[df['age'] < upper_limit]

# %%
sns.boxplot(df['age'], color = 'cyan')
plt.figtext(0.5, -0.02, 'We have dealt with outliers using IQR and Trimming', ha='center', fontsize=10, color='green')
# Out:
# Text(0.5, -0.02, 'We have dealt with outliers using IQR and Trimming')

# %%
from sklearn.model_selection import train_test_split

X = df.drop(['default'],axis = 1)
y = df['default']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
X_train.shape, X_test.shape
# Out:
# ((8792, 16), (2199, 16))

# %% [markdown]
# ### Random Forest Algorithm

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier()
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, y_pred)
# Out:
# array([[2166,    0],
#        [  33,    0]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, y_pred)
print(accuracy)
# Out:
# 0.984993178717599

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(estimator=classifier, X=X_train, y=y_train, cv=10, scoring='accuracy')
# Out:
# array([0.98409091, 0.98409091, 0.98521047, 0.98521047, 0.98521047,
#        0.98521047, 0.98521047, 0.98407281, 0.98407281, 0.98407281])

# %% [markdown]
# ### Adaboost Algorithm

# %%
from sklearn.ensemble import AdaBoostClassifier
classifier = AdaBoostClassifier()
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, y_pred)
# Out:
# array([[2165,    1],
#        [  32,    1]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, y_pred)
print(accuracy)
# Out:
# 0.984993178717599

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(estimator=classifier, X=X_train, y=y_train, cv=10, scoring='accuracy')
# Out:
# array([0.98409091, 0.98295455, 0.98293515, 0.98407281, 0.98521047,
#        0.98748578, 0.98407281, 0.98407281, 0.98407281, 0.98407281])

# %% [markdown]
# ### Developing a model using an artificial neural network (ANN)

# %%
from sklearn.neural_network import MLPClassifier
mlp = MLPClassifier()
mlp.fit(X_train, y_train)
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, y_pred)
# Out:
# array([[2165,    1],
#        [  32,    1]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, y_pred)
print(accuracy)
# Out:
# 0.984993178717599

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(estimator=classifier, X=X_train, y=y_train, cv=10, scoring='accuracy')
# Out:
# array([0.98409091, 0.98295455, 0.98293515, 0.98407281, 0.98521047,
#        0.98748578, 0.98407281, 0.98407281, 0.98407281, 0.98407281])
